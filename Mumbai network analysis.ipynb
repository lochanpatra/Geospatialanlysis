# %%
import osmnx as ox
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
place_name = "mumbai, india"

# %%
graph = ox.graph_from_place(place_name)

# %%
type(graph)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
fig, ax = ox.plot_graph(graph)

# %%
nodes, edges = ox.graph_to_gdfs(graph)

# %%
nodes.head()
# Out:
#                    y          x  street_count highway  \
# osmid
# 245653028  18.906005  72.816399             3     NaN
# 245653033  18.906823  72.816752             3     NaN
# 245653071  18.911485  72.823269             1     NaN
# 245653078  18.911176  72.820864             3     NaN
# 245653086  18.911264  72.819072             3     NaN
#
#                             geometry
# osmid
# 245653028  POINT (72.81640 18.90601)
# 245653033  POINT (72.81675 18.90682)
# 245653071  POINT (72.82327 18.91148)
# 245653078  POINT (72.82086 18.91118)
# 245653086  POINT (72.81907 18.91126)

# %%
nodes.tail()
# Out:
#                      y          x  street_count highway  \
# osmid
# 11143263725  18.960571  72.846756             1     NaN
# 11143596851  18.964178  72.817552             1     NaN
# 11144394052  18.988278  72.810618             1     NaN
# 11145832802  19.021389  72.817081             3     NaN
# 11155263421  19.024437  72.852188             1     NaN
#
#                               geometry
# osmid
# 11143263725  POINT (72.84676 18.96057)
# 11143596851  POINT (72.81755 18.96418)
# 11144394052  POINT (72.81062 18.98828)
# 11145832802  POINT (72.81708 19.02139)
# 11155263421  POINT (72.85219 19.02444)

# %%
edges.head()
# Out:
#                                osmid                                    name  \
# u         v          key
# 245653028 459529385  0      38756487  Nanabhai Moos Marg (Upper Colaba Road)
#           4307040267 0      39492674                             Bakery Lane
#           669252926  0    1165552351                      Nanabhai Moos Marg
# 245653033 459529385  0      38756487  Nanabhai Moos Marg (Upper Colaba Road)
#           2241842244 0      38756487  Nanabhai Moos Marg (Upper Colaba Road)
#
#                               highway  oneway reversed   length  \
# u         v          key
# 245653028 459529385  0        primary   False    False    4.699
#           4307040267 0        primary   False     True  159.726
#           669252926  0    residential   False    False  131.937
# 245653033 459529385  0        primary   False     True   93.823
#           2241842244 0        primary   False    False   44.969
#
#                                                                    geometry  \
# u         v          key
# 245653028 459529385  0    LINESTRING (72.81640 18.90601, 72.81643 18.90604)
#           4307040267 0    LINESTRING (72.81640 18.90601, 72.81619 18.905...
#           669252926  0    LINESTRING (72.81640 18.90601, 72.81622 18.905...
# 245653033 459529385  0    LINESTRING (72.81675 18.90682, 72.81643 18.90604)
#           2241842244 0    LINESTRING (72.81675 18.90682, 72.81685 18.907...
#
#                          lanes service access maxspeed junction bridge tunnel  \
# u         v          key
# 245653028 459529385  0     NaN     NaN    NaN      NaN      NaN    NaN    NaN
#           4307040267 0     NaN     NaN    NaN      NaN      NaN    NaN    NaN
#           669252926  0     NaN     NaN    NaN      NaN      NaN    NaN    NaN
# 245653033 459529385  0     NaN     NaN    NaN      NaN      NaN    NaN    NaN
#           2241842244 0     NaN     NaN    NaN      NaN      NaN    NaN    NaN
#
#                           ref width
# u         v          key
# 245653028 459529385  0    NaN   NaN
#           4307040267 0    NaN   NaN
#           669252926  0    NaN   NaN
# 245653033 459529385  0    NaN   NaN
#           2241842244 0    NaN   NaN

# %%
edges.tail()
# Out:
#                                                osmid name      highway  \
# u           v           key
# 11144394052 529848089   0                 1202050499  NaN  residential
# 11145832802 11054595591 0    [1190570970, 785325550]  NaN  residential
#             5516419792  0                  785325550  NaN  residential
#             10576206724 0                 1202479805  NaN  residential
# 11155263421 7371795879  0                 1203396974  NaN      service
#
#                              oneway       reversed   length  \
# u           v           key
# 11144394052 529848089   0     False           True  443.539
# 11145832802 11054595591 0     False  [False, True]   88.521
#             5516419792  0     False           True   81.593
#             10576206724 0     False           True   15.830
# 11155263421 7371795879  0     False           True   31.728
#
#                                                                       geometry  \
# u           v           key
# 11144394052 529848089   0    LINESTRING (72.81062 18.98828, 72.81072 18.987...
# 11145832802 11054595591 0    LINESTRING (72.81708 19.02139, 72.81702 19.021...
#             5516419792  0    LINESTRING (72.81708 19.02139, 72.81711 19.021...
#             10576206724 0    LINESTRING (72.81708 19.02139, 72.81710 19.021...
# 11155263421 7371795879  0    LINESTRING (72.85219 19.02444, 72.85224 19.024...
#
#                             lanes service access maxspeed junction bridge  \
# u           v           key
# 11144394052 529848089   0     NaN     NaN    NaN      NaN      NaN    NaN
# 11145832802 11054595591 0     NaN     NaN    NaN      NaN      NaN    NaN
#             5516419792  0     NaN     NaN    NaN      NaN      NaN    NaN
#             10576206724 0     NaN     NaN    NaN      NaN      NaN    NaN
# 11155263421 7371795879  0     NaN     NaN    NaN      NaN      NaN    NaN
#
#                             tunnel  ref width
# u           v           key
# 11144394052 529848089   0      NaN  NaN   NaN
# 11145832802 11054595591 0      NaN  NaN   NaN
#             5516419792  0      NaN  NaN   NaN
#             10576206724 0      NaN  NaN   NaN
# 11155263421 7371795879  0      NaN  NaN   NaN

# %%
edges.columns
# Out:
# Index(['osmid', 'name', 'highway', 'oneway', 'reversed', 'length', 'geometry',
#        'lanes', 'service', 'access', 'maxspeed', 'junction', 'bridge',
#        'tunnel', 'ref', 'width'],
#       dtype='object')

# %%
edges['highway'].value_counts()
# Out:
# highway
# residential                                  10172
# service                                       8079
# secondary                                     2721
# tertiary                                      2391
# footway                                       1710
# primary                                       1329
# path                                          1192
# living_street                                  557
# trunk                                          298
# steps                                          194
# [footway, steps]                               186
# primary_link                                   123
# pedestrian                                      74
# [service, residential]                          70
# secondary_link                                  35
# [footway, residential]                          34
# trunk_link                                      27
# [living_street, residential]                    26
# tertiary_link                                   25
# track                                           22
# [path, steps]                                   16
# [footway, path]                                 16
# [pedestrian, footway, steps]                    14
# [footway, path, steps]                          14
# [service, footway]                              12
# [footway, steps, residential]                   10
# [steps, residential]                            10
# unclassified                                     8
# [path, residential]                              8
# motorway                                         7
# [pedestrian, footway]                            6
# motorway_link                                    5
# [footway, living_street]                         4
# [service, tertiary]                              4
# [service, footway, steps]                        4
# [secondary, primary]                             3
# [service, living_street]                         2
# [tertiary, residential]                          2
# [service, path]                                  2
# [service, living_street, path]                   2
# [pedestrian, residential]                        2
# [pedestrian, footway, steps, residential]        2
# [motorway, motorway_link]                        2
# [living_street, steps]                           2
# [service, steps]                                 2
# [secondary, residential]                         2
# [footway, path, residential]                     2
# [pedestrian, steps, residential]                 2
# [service, footway, residential]                  2
# [service, pedestrian]                            2
# [primary_link, primary]                          1
# [secondary_link, secondary]                      1
# [residential, primary]                           1
# Name: count, dtype: int64

# %%
edges['oneway'].value_counts()
# Out:
# oneway
# False    24208
# True      5229
# Name: count, dtype: int64

# %%
edges['tunnel'].value_counts()
# Out:
# tunnel
# yes                 60
# building_passage     4
# Name: count, dtype: int64

# %%
edges.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
place_polygon = ox.geocode_to_gdf(place_name)

# %%
# Re-project the polygon back to WGS84, as required by osmnx
#place_polygon = place_polygon.to_crs(epsg=4326)

# %%
# Retrieve the network
graph = ox.graph_from_polygon(place_polygon["geometry"].values[0], network_type='bike')

# %%
fig, ax = ox.plot_graph(graph)

# %%
area = ox.geocode_to_gdf(place_name)

# %%
area
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  MULTIPOLYGON (((72.79156 18.94888, 72.79167 18...   19.052585   18.893957
#
#    bbox_east  bbox_west   place_id  osm_type   osm_id        lat        lon  \
# 0  72.906814  72.791557  298662916  relation  7964376  18.973354  72.828105
#
#       class            type  place_rank  importance addresstype    name  \
# 0  boundary  administrative          10     0.65995        city  Mumbai
#
#                  display_name
# 0  Mumbai, Maharashtra, India

# %%
area.plot()
# Out:
# <Axes: >

# %%
tags = {'building': True}

# %%
buildings = ox.geometries_from_place(place_name, tags)
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_5516\2443088457.py:1: UserWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in a future release.
#   buildings = ox.geometries_from_place(place_name, tags)

# %%
len(buildings)
# Out:
# 21464

# %%
buildings.head()
# Out:
#                         source                   geometry  \
# element_type osmid
# node         852836750     NaN  POINT (72.82125 18.92536)
#              925978255     NaN  POINT (72.82172 18.95894)
#              1383322788    NaN  POINT (72.84289 19.04197)
#              1593475880    NaN  POINT (72.81017 18.97440)
#              1679689272    NaN  POINT (72.80238 18.95210)
#
#                                                     name addr:city  \
# element_type osmid
# node         852836750   German Consulate General Mumbai    Mumbai
#              925978255                               NaN       NaN
#              1383322788                       Rediff.com       NaN
#              1593475880                              NaN       NaN
#              1679689272                          Purnima       NaN
#
#                                        addr:housename addr:housenumber  \
# element_type osmid
# node         852836750                  Hoechst House              193
#              925978255                            NaN              NaN
#              1383322788  Mahalaxmi Engineering Estate        1st Floor
#              1593475880            Future East Bureau                8
#              1679689272                           NaN              NaN
#
#                         addr:postcode                         addr:street  \
# element_type osmid
# node         852836750        400 021  Backbay Reclamation, Nariman Point
#              925978255            NaN                                 NaN
#              1383322788        400016                      L.J. Road No.1
#              1593475880           NaN                       Carmichael Rd
#              1679689272           NaN                                 NaN
#
#                               building          consulate  ... aeroway  \
# element_type osmid                                         ...
# node         852836750   Hoechst House  consulate_general  ...     NaN
#              925978255     residential                NaN  ...     NaN
#              1383322788            yes                NaN  ...     NaN
#              1593475880     apartments                NaN  ...     NaN
#              1679689272     apartments                NaN  ...     NaN
#
#                         service_times swimming_pool male not:brand:wikidata  \
# element_type osmid
# node         852836750            NaN           NaN  NaN                NaN
#              925978255            NaN           NaN  NaN                NaN
#              1383322788           NaN           NaN  NaN                NaN
#              1593475880           NaN           NaN  NaN                NaN
#              1679689272           NaN           NaN  NaN                NaN
#
#                         tower:type ways image name:alt grades
# element_type osmid
# node         852836750         NaN  NaN   NaN      NaN    NaN
#              925978255         NaN  NaN   NaN      NaN    NaN
#              1383322788        NaN  NaN   NaN      NaN    NaN
#              1593475880        NaN  NaN   NaN      NaN    NaN
#              1679689272        NaN  NaN   NaN      NaN    NaN
#
# [5 rows x 175 columns]

# %%
buildings.columns
# Out:
# Index(['source', 'geometry', 'name', 'addr:city', 'addr:housename',
#        'addr:housenumber', 'addr:postcode', 'addr:street', 'building',
#        'consulate',
#        ...
#        'aeroway', 'service_times', 'swimming_pool', 'male',
#        'not:brand:wikidata', 'tower:type', 'ways', 'image', 'name:alt',
#        'grades'],
#       dtype='object', length=175)

# %%
buildings.plot()
# Out:
# <Axes: >

# %%
buildings['swimming_pool'].value_counts()
# Out:
# swimming_pool
# outdoor    1
# Name: count, dtype: int64

# %%
buildings['addr:postcode'].value_counts()
# Out:
# addr:postcode
# 400014     252
# 400008      92
# 400019      63
# 400005      56
# 400001      34
# 400002      28
# 400009      27
# 400016      20
# 400012      20
# 400003      18
# 400004      18
# 400018      16
# 400013      14
# 400025      13
# 400022      13
# 400028      13
# 400031      13
# 400034      12
# 400021      12
# 400026      11
# 400020      11
# 400007      10
# 400030       9
# 400037       8
# 400027       8
# 400033       7
# 400010       7
# 400006       5
# 400011       4
# 400015       3
# 400036       2
# 400038       1
# 400 021      1
# 400706       1
# 400023       1
# 40001        1
# 400032       1
# 400088       1
# 400039       1
# 3            1
# Name: count, dtype: int64

# %%
tags = {'amenity': 'restaurant'}

# %%
restaurants = ox.geometries_from_place(place_name, tags)
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_5516\2807289861.py:1: UserWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in a future release.
#   restaurants = ox.geometries_from_place(place_name, tags)

# %%
len(restaurants)
# Out:
# 201

# %%
restaurants.columns.values
# Out:
# array(['amenity', 'name', 'source', 'geometry', 'addr:city',
#        'addr:housename', 'addr:postcode', 'addr:street', 'cuisine',
#        'opening_hours', 'smoking', 'phone', 'addr:housenumber', 'url',
#        'website', 'diet:vegetarian', 'microbrewery', 'wifi', 'name:en',
#        'delivery', 'takeaway', 'internet_access', 'outdoor_seating',
#        'air_conditioning', 'bar', 'alt_name', 'name:ru', 'note',
#        'name:gu', 'contact:facebook', 'contact:instagram',
#        'contact:phone', 'contact:tripadvisor', 'contact:twitter',
#        'contact:website', 'diet:meat', 'self_service', 'diet:vegan',
#        'name:ar', 'name:es', 'name:km', 'addr:country', 'addr:state',
#        'level', 'contact:mobile', 'diet:jain', 'diet:gluten_free',
#        'addr:place', 'diet:halal', 'diet:non-vegetarian', 'nodes',
#        'building', 'wikidata', 'date', 'tourism'], dtype=object)

# %%
restaurants.plot(color="red")
# Out:
# <Axes: >

# %%
# Select some useful cols and print
cols = ['name', 'opening_hours', 'addr:city', 'addr:country', 
        'addr:housenumber', 'addr:postcode', 'addr:street']

# Print only selected cols
restaurants[cols].head(10)
# Out:
#                                          name opening_hours addr:city  \
# element_type osmid
# node         245653876         Copper Chimney           NaN       NaN
#              459667350               Jai Hind           NaN       NaN
#              610270325             Ever Green           NaN       NaN
#              610271821                Shriram           NaN       NaN
#              623344544       New Martin Hotel           NaN       NaN
#              662459670      Mahesh Lunch Home           NaN       NaN
#              662459710           Mocambo Cafe           NaN       NaN
#              662488867       On Toes Restobar           NaN       NaN
#              662488869           Ideal Corner           NaN       NaN
#              662488870  Excellency Restaurant           NaN       NaN
#
#                        addr:country addr:housenumber addr:postcode addr:street
# element_type osmid
# node         245653876          NaN              NaN           NaN         NaN
#              459667350          NaN              NaN           NaN         NaN
#              610270325          NaN              NaN           NaN         NaN
#              610271821          NaN              NaN           NaN         NaN
#              623344544          NaN              NaN           NaN         NaN
#              662459670          NaN              NaN           NaN         NaN
#              662459710          NaN              NaN           NaN         NaN
#              662488867          NaN              NaN           NaN         NaN
#              662488869          NaN              NaN           NaN         NaN
#              662488870          NaN              NaN           NaN         NaN

# %%
tags = {'leisure': 'park', 'landuse': 'grass'}

# %%
parks = ox.geometries_from_place(place_name, tags)
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_5516\1748763681.py:1: UserWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in a future release.
#   parks = ox.geometries_from_place(place_name, tags)

# %%
parks.head()
# Out:
#                         source                   geometry barrier leisure  \
# element_type osmid
# node         2930734687    NaN  POINT (72.82990 18.95123)     NaN    park
#              3202779969    NaN  POINT (72.83974 18.94984)     NaN    park
#              3202928822    NaN  POINT (72.86281 19.01963)     NaN    park
#              3420965905    NaN  POINT (72.81456 18.96714)     NaN    park
#              5330860952    NaN  POINT (72.83048 18.92465)     NaN    park
#
#                                                                       name  \
# element_type osmid
# node         2930734687                                         green park
#              3202779969                                     s k nizam park
#              3202928822                                         santi park
#              3420965905                                                NaN
#              5330860952  Sabina Chandrashekhar Memorial Municipal Garde...
#
#                         addr:city               addr:housenumber  \
# element_type osmid
# node         2930734687       NaN                            NaN
#              3202779969       NaN                            NaN
#              3202928822       NaN                            NaN
#              3420965905       NaN                            NaN
#              5330860952    Mumbai  Dr Ambedkar Statue Chowk Area
#
#                         addr:postcode              addr:street addr:unit  ...  \
# element_type osmid                                                        ...
# node         2930734687           NaN                      NaN       NaN  ...
#              3202779969           NaN                      NaN       NaN  ...
#              3202928822           NaN                      NaN       NaN  ...
#              3420965905           NaN                      NaN       NaN  ...
#              5330860952        400001  Nathalal M. Parikh Road    Colaba  ...
#
#                         alt_name natural features place historic:landuse  \
# element_type osmid
# node         2930734687      NaN     NaN      NaN   NaN              NaN
#              3202779969      NaN     NaN      NaN   NaN              NaN
#              3202928822      NaN     NaN      NaN   NaN              NaN
#              3420965905      NaN     NaN      NaN   NaN              NaN
#              5330860952      NaN     NaN      NaN   NaN              NaN
#
#                         historic:name  dog name:hi ownership golf
# element_type osmid
# node         2930734687           NaN  NaN     NaN       NaN  NaN
#              3202779969           NaN  NaN     NaN       NaN  NaN
#              3202928822           NaN  NaN     NaN       NaN  NaN
#              3420965905           NaN  NaN     NaN       NaN  NaN
#              5330860952           NaN  NaN     NaN       NaN  NaN
#
# [5 rows x 39 columns]

# %%
parks.columns.values
# Out:
# array(['source', 'geometry', 'barrier', 'leisure', 'name', 'addr:city',
#        'addr:housenumber', 'addr:postcode', 'addr:street', 'addr:unit',
#        'access', 'opening_hours', 'operator', 'nodes', 'description',
#        'name:etymology:wikidata', 'wikidata', 'wikipedia', 'addr:country',
#        'addr:state', 'footway', 'historic', 'old_name', 'landuse',
#        'name:mr', 'short_name', 'website', 'surface', 'addr:district',
#        'alt_name', 'natural', 'features', 'place', 'historic:landuse',
#        'historic:name', 'dog', 'name:hi', 'ownership', 'golf'],
#       dtype=object)

# %%
parks.plot(color="blue")
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(12,8))

# Plot the footprint
area.plot(ax=ax, facecolor='black')

# Plot street edges
edges.plot(ax=ax, linewidth=1, edgecolor='dimgray')

# Plot buildings
buildings.plot(ax=ax, facecolor='silver', alpha=0.7)

# Plot restaurants
restaurants.plot(ax=ax, color='yellow', alpha=0.7, markersize=10)
plt.tight_layout()
